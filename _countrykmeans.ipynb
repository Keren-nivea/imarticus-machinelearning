# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
rdata=pd.read_csv('C:/Users/keren/OneDrive/Desktop/Country.csv')

# %%
rdata
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# 1         4.49        76.3       1.65   4090
# 2        16.10        76.5       2.89   4460
# 3        22.40        60.1       6.16   3530
# 4         1.44        76.8       2.13  12200
# ..         ...         ...        ...    ...
# 162       2.62        63.0       3.50   2970
# 163      45.90        75.4       2.47  13500
# 164      12.10        73.1       1.95   1310
# 165      23.60        67.5       4.67   1310
# 166      14.00        52.0       5.40   1460
#
# [167 rows x 10 columns]

# %%
rdata.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# 50%      5.390000   73.100000    2.410000    4660.000000
# 75%     10.750000   76.800000    3.880000   14050.000000
# max    104.000000   82.800000    7.490000  105000.000000

# %%
print(rdata.shape)
# Out:
# (167, 10)

# %%
sns.countplot(data=rdata,x='child_mort')
plt.title('Distribution of child mort',fontsize=5)
plt.xlabel('child_mort')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
rdata.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# 50%      5.390000   73.100000    2.410000    4660.000000
# 75%     10.750000   76.800000    3.880000   14050.000000
# max    104.000000   82.800000    7.490000  105000.000000

# %%
rdata.describe(include=object)
# Out:
#             country
# count           167
# unique          167
# top     Afghanistan
# freq              1

# %%
rdata.describe(include='all')
# Out:
#             country  child_mort     exports      health     imports  \
# count           167  167.000000  167.000000  167.000000  167.000000
# unique          167         NaN         NaN         NaN         NaN
# top     Afghanistan         NaN         NaN         NaN         NaN
# freq              1         NaN         NaN         NaN         NaN
# mean            NaN   38.270060   41.108976    6.815689   46.890215
# std             NaN   40.328931   27.412010    2.746837   24.209589
# min             NaN    2.600000    0.109000    1.810000    0.065900
# 25%             NaN    8.250000   23.800000    4.920000   30.200000
# 50%             NaN   19.300000   35.000000    6.320000   43.300000
# 75%             NaN   62.100000   51.350000    8.600000   58.750000
# max             NaN  208.000000  200.000000   17.900000  174.000000
#
#                income   inflation  life_expec   total_fer           gdpp
# count      167.000000  167.000000  167.000000  167.000000     167.000000
# unique            NaN         NaN         NaN         NaN            NaN
# top               NaN         NaN         NaN         NaN            NaN
# freq              NaN         NaN         NaN         NaN            NaN
# mean     17144.688623    7.781832   70.555689    2.947964   12964.155689
# std      19278.067698   10.570704    8.893172    1.513848   18328.704809
# min        609.000000   -4.210000   32.100000    1.150000     231.000000
# 25%       3355.000000    1.810000   65.300000    1.795000    1330.000000
# 50%       9960.000000    5.390000   73.100000    2.410000    4660.000000
# 75%      22800.000000   10.750000   76.800000    3.880000   14050.000000
# max     125000.000000  104.000000   82.800000    7.490000  105000.000000

# %%
total=rdata.isnull().sum().sort_values(ascending=False)

percent=(rdata.isnull().sum()/rdata.isnull().count()*100).sort_values(ascending=False)

missing=pd.concat([total,percent],axis=1,keys=['total','percent'])
missing
# Out:
#             total  percent
# country         0      0.0
# child_mort      0      0.0
# exports         0      0.0
# health          0      0.0
# imports         0      0.0
# income          0      0.0
# inflation       0      0.0
# life_expec      0      0.0
# total_fer       0      0.0
# gdpp            0      0.0

# %%
sns.heatmap(rdata.isnull(),cbar=False)

plt.title('Heatmap for missing values',fontsize=15)
plt.xlabel('variables')
plt.ylabel('id')
# Out:
# Text(47.25, 0.5, 'id')

# %%
fig=rdata.hist(figsize=(18,18))

# %%
rdata.shape
# Out:
# (167, 10)

# %%
features=rdata.drop(['country'],axis=1)
features.head()
# Out:
#    child_mort  exports  health  imports  income  inflation  life_expec  \
# 0        90.2     10.0    7.58     44.9    1610       9.44        56.2
# 1        16.6     28.0    6.55     48.6    9930       4.49        76.3
# 2        27.3     38.4    4.17     31.4   12900      16.10        76.5
# 3       119.0     62.3    2.85     42.9    5900      22.40        60.1
# 4        10.3     45.5    6.03     58.9   19100       1.44        76.8
#
#    total_fer   gdpp
# 0       5.82    553
# 1       1.65   4090
# 2       2.89   4460
# 3       6.16   3530
# 4       2.13  12200

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler().fit(features)
features=scale.transform(features)

# %%
features_scaled=pd.DataFrame(features,columns=rdata.columns[0:9])
features_scaled.head()
# Out:
#     country  child_mort   exports    health   imports    income  inflation  \
# 0  1.291532   -1.138280  0.279088 -0.082455 -0.808245  0.157336  -1.619092
# 1 -0.538949   -0.479658 -0.097016  0.070837 -0.375369 -0.312347   0.647866
# 2 -0.272833   -0.099122 -0.966073 -0.641762 -0.220844  0.789274   0.670423
# 3  2.007808    0.775381 -1.448071 -0.165315 -0.585043  1.387054  -1.179234
# 4 -0.695634    0.160668 -0.286894  0.497568  0.101732 -0.601749   0.704258
#
#    life_expec  total_fer
# 0    1.902882  -0.679180
# 1   -0.859973  -0.485623
# 2   -0.038404  -0.465376
# 3    2.128151  -0.516268
# 4   -0.541946  -0.041817

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
n_clusters=[4,5,6,7,8]

for k in n_clusters:
    cluster=KMeans(n_clusters=k,random_state=10)
    predict=cluster.fit_predict(features_scaled)
    score=silhouette_score(features_scaled,predict,random_state=10)
    print('For n_clusters={},silhoutte score is {})'.format(k,score))
# Out:
# For n_clusters=4,silhoutte score is 0.1972834948654735)
# For n_clusters=5,silhoutte score is 0.22340297055780237)
# For n_clusters=6,silhoutte score is 0.23949517490114236)
# For n_clusters=7,silhoutte score is 0.21907840394012765)
# For n_clusters=8,silhoutte score is 0.21385279101491475)
# C:\Users\keren\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\keren\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\keren\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\keren\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\keren\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
model=KMeans(n_clusters=4,random_state=10)
model.fit(features_scaled)
# Out:
# C:\Users\keren\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4, random_state=10)

# %%
data_output=rdata.copy(deep=True)

data_output['Cluster']=model.labels_
data_output.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp  Cluster
# 0       9.44        56.2       5.82    553        3
# 1       4.49        76.3       1.65   4090        2
# 2      16.10        76.5       2.89   4460        1
# 3      22.40        60.1       6.16   3530        3
# 4       1.44        76.8       2.13  12200        2

# %%
np.unique(model.labels_,return_counts=True)
# Out:
# (array([0, 1, 2, 3]), array([30, 45, 53, 39], dtype=int64))

# %%
sns.countplot(data= data_output, x = 'Cluster')

# set the axes and plot labels
# set the font size using 'fontsize'
plt.title('Cluster Sizes', fontsize = 15)
plt.xlabel('Clusters', fontsize = 15)
plt.ylabel('No. of Customers', fontsize = 15)

# add values in the graph
# 'x' and 'y' assigns the position to the text
# 's' represents the text on the plot
plt.text(x = -0.18, y =2000, s = np.unique(model.labels_, return_counts=True)[1][0])
plt.text(x = 0.9, y =2000, s = np.unique(model.labels_, return_counts=True)[1][1])
plt.text(x = 1.85, y =2000, s = np.unique(model.labels_, return_counts=True)[1][2])
plt.text(x = 2.85, y =2000, s = np.unique(model.labels_, return_counts=True)[1][3])

plt.show()

# %%
centers = pd.DataFrame(model.cluster_centers_, columns=  data_output.columns[0:9])  
centers.head()
# Out:
#     country  child_mort   exports    health   imports    income  inflation  \
# 0 -0.830019    0.491320  0.803078 -0.010643  1.643854 -0.473757   1.124191
# 1 -0.091111   -0.444874 -0.559134 -0.600732 -0.355980  0.364706  -0.034602
# 2 -0.573111    0.435232  0.083630  0.592388 -0.087426 -0.323755   0.392506
# 3  1.522447   -0.456091 -0.086249 -0.103701 -0.734948  0.383590  -1.358243
#
#    life_expec  total_fer
# 0   -0.764123   1.855440
# 1   -0.105396  -0.435122
# 2   -0.603326  -0.220199
# 3    1.529303  -0.625953

# %%
cluster_1 = sorted(zip(list(centers.iloc[0,:]), list(centers.columns)), reverse = True)[:10]

# %%
np.unique(model.labels_, return_counts=True)[1][0]
# Out:
# 30

# %%
cluster1_var = pd.DataFrame(cluster_1)[1]
cluster1_var
# Out:
# 0     total_fer
# 1       imports
# 2     inflation
# 3       exports
# 4    child_mort
# 5        health
# 6        income
# 7    life_expec
# 8       country
# Name: 1, dtype: object

# %%
data_output[['country', 'Cluster']][data_output.Cluster == 0].describe()
# Out:
#        Cluster
# count     30.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %%
cluster_2 = sorted(zip(list(centers.iloc[1,:]), list(centers.columns)), reverse = True)[:10]

# %%
np.unique(model.labels_, return_counts=True)[1][1]
# Out:
# 45

# %%
cluster2_var = pd.DataFrame(cluster_2)[1]
cluster2_var
# Out:
# 0        income
# 1     inflation
# 2       country
# 3    life_expec
# 4       imports
# 5     total_fer
# 6    child_mort
# 7       exports
# 8        health
# Name: 1, dtype: object

# %%
data_output[['country', 'Cluster']][data_output.Cluster == 1].describe()
# Out:
#        Cluster
# count     45.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0

# %%
cluster_3 = sorted(zip(list(centers.iloc[2,:]), list(centers.columns)), reverse = True)[:10]

# %%
np.unique(model.labels_, return_counts=True)[1][2]
# Out:
# 53

# %%
cluster3_var = pd.DataFrame(cluster_3)[1]
cluster3_var
# Out:
# 0        health
# 1    child_mort
# 2     inflation
# 3       exports
# 4       imports
# 5     total_fer
# 6        income
# 7       country
# 8    life_expec
# Name: 1, dtype: object

# %%
data_output[['country', 'Cluster']][data_output.Cluster == 2].describe()
# Out:
#        Cluster
# count     53.0
# mean       2.0
# std        0.0
# min        2.0
# 25%        2.0
# 50%        2.0
# 75%        2.0
# max        2.0

# %%
cluster_4 = sorted(zip(list(centers.iloc[3,:]), list(centers.columns)), reverse=True)[:10]

# %%
np.unique(model.labels_, return_counts=True)[1][3]
# Out:
# 39

# %%
cluster4_var = pd.DataFrame(cluster_4)[1]
cluster4_var
# Out:
# 0    life_expec
# 1       country
# 2        income
# 3       exports
# 4        health
# 5    child_mort
# 6     total_fer
# 7       imports
# 8     inflation
# Name: 1, dtype: object

# %%
data_output[['country', 'Cluster']][data_output.Cluster==3].describe()
# Out:
#        Cluster
# count     39.0
# mean       3.0
# std        0.0
# min        3.0
# 25%        3.0
# 50%        3.0
# 75%        3.0
# max        3.0
